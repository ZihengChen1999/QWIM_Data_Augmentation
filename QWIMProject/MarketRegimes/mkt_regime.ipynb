# %%
from mg_funcs import *
# %matplotlib inline

# %%
df = pd.read_csv('test5yr_mkt_reg.csv', header = 0,index_col='Date')
df.index = pd.to_datetime(df.index)
df = df.dropna()
df.head()
# Out:
#               AAPL     DIS     CSCO  GBPUSD    TNX     HG1  METAL_INDEX  \
# Date
# 2016-01-05  25.677  100.90  119.259  1.4675  22.48  2.0920       135.21
# 2016-01-06  25.175  100.36  119.144  1.4630  21.77  2.0845       133.45
# 2016-01-07  24.112   99.50  119.666  1.4618  21.53  2.0185       131.18
# 2016-01-08  24.240   99.25  119.618  1.4517  21.30  2.0185       131.69
# 2016-01-11  24.632   99.92  120.111  1.4543  21.58  1.9705       129.84
#
#             BOND_INDEX      SPX
# Date
# 2016-01-05     2583.04  2016.71
# 2016-01-06     2582.20  1990.26
# 2016-01-07     2585.65  1943.09
# 2016-01-08     2579.56  1922.03
# 2016-01-11     2588.38  1923.67

# %%
# copper
hg = Mkt_regime(df[['HG1']])
hg_h = hg.hidden_states()
hg_h.to_csv('hg1_states.csv')
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [2.14425271e+00 3.33212303e-04]
# var =  [0.00642717 0.00020748]
#
# 1th hidden state
# mean =  [2.79574604e+00 3.90300367e-04]
# var =  [0.0560719  0.00014912]
#
# 2th hidden state
# mean =  [4.07669723e+00 1.58549526e-03]
# var =  [0.16900483 0.00022964]
#
#         Date  states  Lst_price      sret  mkt_cret Ticker
# 0 2016-01-06       0     2.0845 -0.003592 -0.003592    HG1
# 1 2016-01-07       0     2.0185 -0.032174 -0.035766    HG1
# 2 2016-01-08       0     2.0185  0.000000 -0.035766    HG1
# 3 2016-01-11       0     1.9705 -0.024067 -0.059833    HG1
# 4 2016-01-12       0     1.9570 -0.006875 -0.066708    HG1

# %%
hg.histor_regime('Lst_price')
# Out:
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# 0

# %%
csco = Mkt_regime(df[['CSCO']])
gbpusd = Mkt_regime(df[['GBPUSD']])
tnx = Mkt_regime(df[['TNX']])

# %%
csco_h = csco.hidden_states(2)
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [1.24084721e+02 1.92155345e-04]
# var =  [1.95088346e+01 2.85133183e-05]
#
# 1th hidden state
# mean =  [1.41076372e+02 3.16923389e-05]
# var =  [4.49253304e+01 8.54138467e-05]
#
#         Date  states  Lst_price      sret  mkt_cret Ticker
# 0 2016-01-06       0    119.144 -0.000965 -0.000965   CSCO
# 1 2016-01-07       0    119.666  0.004372  0.003407   CSCO
# 2 2016-01-08       0    119.618 -0.000401  0.003006   CSCO
# 3 2016-01-11       0    120.111  0.004113  0.007119   CSCO
# 4 2016-01-12       0    119.024 -0.009091 -0.001972   CSCO

# %%
csco_h.to_csv('csco_states.csv')

# %%
csco.hidden_states_plot(2)
# Out:
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# 0

# %%
csco.histor_regime('Lst_price')
# Out:
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# 0

# %%
#appl hidden states 
aapl_h = aapl.hidden_states()
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [1.26412086e+02 1.61943382e-03]
# var =  [1.03136464e+02 3.88680168e-04]
#
# 1th hidden state
# mean =  [6.23144951e+01 9.25669367e-04]
# var =  [4.14490567e+02 9.60967147e-04]
#
# 2th hidden state
# mean =  [3.92149808e+01 1.28185308e-03]
# var =  [1.05760342e+02 1.11985434e-04]
#
#         Date  states  Lst_price      sret  mkt_cret Ticker
# 0 2016-01-06       2     25.175 -0.019744 -0.019744   AAPL
# 1 2016-01-07       1     24.112 -0.043142 -0.062886   AAPL
# 2 2016-01-08       2     24.240  0.005295 -0.057591   AAPL
# 3 2016-01-11       2     24.632  0.016042 -0.041549   AAPL
# 4 2016-01-12       2     24.990  0.014429 -0.027120   AAPL

# %%
aapl_h.to_csv('appl_states.csv')

# %%
aapl.histor_regime('Lst_price')
# Out:
# 0

# %%
gbpusd_h = gbpusd.hidden_states(2)
gbpusd_h.to_csv('gbpusd_states.csv')
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [1.28943970e+00 3.18073994e-05]
# var =  [1.61439320e-03 3.66440293e-05]
#
# 1th hidden state
# mean =  [ 1.40775675e+00 -2.87560839e-04]
# var =  [8.76189856e-04 5.82129249e-05]
#
#         Date  states  Lst_price      sret  mkt_cret  Ticker
# 0 2016-01-06       1     1.4630 -0.003071 -0.003071  GBPUSD
# 1 2016-01-07       1     1.4618 -0.000821 -0.003892  GBPUSD
# 2 2016-01-08       1     1.4517 -0.006933 -0.010825  GBPUSD
# 3 2016-01-11       1     1.4543  0.001789 -0.009036  GBPUSD
# 4 2016-01-12       1     1.4448 -0.006554 -0.015589  GBPUSD

# %%
gbpusd.hidden_states_plot(2)
# Out:
# 0

# %%
gbpusd.histor_regime('Lst_price')
# Out:
# 0

# %%
tnx_h = tnx.hidden_states()
tnx_h.to_csv('tnx_states.csv')
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [ 2.55261578e+01 -8.25170053e-05]
# var =  [1.15212671e+01 1.85480090e-04]
#
# 1th hidden state
# mean =  [ 7.67347951e+00 -1.03199899e-03]
# var =  [2.33846168 0.00590263]
#
# 2th hidden state
# mean =  [ 1.66744547e+01 -5.55965319e-04]
# var =  [4.98811381e+00 7.88698694e-04]
#
#         Date  states  Lst_price      sret  mkt_cret Ticker
# 0 2016-01-06       0      21.77 -0.032093 -0.032093    TNX
# 1 2016-01-07       0      21.53 -0.011086 -0.043179    TNX
# 2 2016-01-08       0      21.30 -0.010740 -0.053919    TNX
# 3 2016-01-11       0      21.58  0.013060 -0.040859    TNX
# 4 2016-01-12       0      21.02 -0.026293 -0.067152    TNX

# %%
tnx.hidden_states_plot()
# Out:
# 0

# %%
tnx.histor_regime('Lst_price')
# Out:
# 0
